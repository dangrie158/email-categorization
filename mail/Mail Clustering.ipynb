# %%
from gensim.models import Word2Vec
#for timing
import time
# Out:
# /Users/daniel/Library/Python/2.7/lib/python/site-packages/gensim/utils.py:1015: UserWarning: Pattern library is not installed, lemmatization won't be available.
#   warnings.warn("Pattern library is not installed, lemmatization won't be available.")

# %%
print('loading HdM model')
hdm_base = Word2Vec.load('data/hdm.word2vec.model')
print('loading Non-HdM model')
nonhdm_base = Word2Vec.load('data/non-hdm.word2vec.model')
# Out:
# loading HdM model
# loading Non-HdM model

# %%
model = nonhdm_base
word_vectors = model.syn0
num_clusters = word_vectors.shape[0] / 1000

# %%
from sklearn.cluster import KMeans

# %%
k_clustering = KMeans( n_clusters = num_clusters )

# %%
start = time.time()
idx = k_clustering.fit_predict( word_vectors )

end = time.time()

print('time for clustering: {}s'.format(end - start))

# Create a Word / Index dictionary, mapping each vocabulary word to
# a cluster number                                                                                            
word_centroid_map = dict(zip( model.index2word, idx ))
# Out:
# time for clustering: 131.563278913s

# %%
for cluster in xrange(0,10):
    #
    # Print the cluster number  
    print "\nCluster %d" % cluster
    #
    # Find all of the words for that cluster number, and print them out
    words = []
    for i in xrange(0,len(word_centroid_map.values())):
        if( word_centroid_map.values()[i] == cluster ):
            words.append(word_centroid_map.keys()[i])
    print words
# Out:
# Cluster 0
# ...
